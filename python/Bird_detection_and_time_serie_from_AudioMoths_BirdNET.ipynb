# %% [markdown]
# # Script for project: "Developing a biodiversity driven, gamified outdoor application for children by merging forest LiDAR data and Audiomoth sensors"

# %% [markdown]
# This script detect the bird species using data gathered using AudioMoths sensors.
#
# The script works trought the following steps:
#
# 1. It loads the BirdNET neural network. Capable to detect bird species using audio (.WAV) data.
# 2. The birdNET is run for each plot using the raw .WAV as input, day of the year and coordinates.
# 3. The outputs of the BirdNET are exported in .txt format containing all the species detected, when was detected and the conffidence of the algorithm about the detected specie.
# 4. The data is loaded and the number of species and number of detections is reported per site.
# 5. The data is visualized in a interactive time serie plot using plotly library displaying the number of birds per specie per hour of the day and site.
# 6. Finally, the interactive plots are exported in .html format.

# %%
# !pip install birdnetlib

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from birdnetlib import Recording
from birdnetlib.analyzer import Analyzer
from datetime import datetime
import glob
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import plotly.graph_objects as go
import plotly.express as px

# %%
# Commented since sensor 1 failed 

# # plot number: (1) 
# # Plot name: Forest entrance 
# # ID: 242A260460371506
# # Coordinates (lat, lon): 52.02836528, 6.65406257 
# # Start date time: 24-05-2023 10:34
# # End date time: 25-05-2023 09:50
# # Comments: removed because it was not properly deployed

# analyzer = Analyzer()

# recording = Recording(
#     analyzer,
#     "",
#     lat=52.02836528,
#     lon=6.65406257,
#     date=datetime(year=2023, month=5, day=24), 
#     min_conf=0.5,
# )
# recording.analyze()
# print(recording.detections)

# %%
# plot number: (2) 
# Plot name: Field
# ID: 24F31901603716F4
# Coordinates (lat, lon): 52.02751446, 6.65145370
# Start date time: 24-05-2023 10:51
# End date time: 25-05-2023 9:56
# Comments: 

folder = '/content/drive/MyDrive/IDV/data/audio/BirdNET/2_field/*.WAV'
files = glob.glob(folder)

full_data = []

for i in range(0, len(files)):
  
  analyzer = Analyzer()

  recording = Recording(
      analyzer,
      files[i],
      lat=52.02751446,
      lon=6.65145370,
      date=datetime(year=2023, month=5, day=24), 
      min_conf=0.5,
  )
  recording.analyze()

  day = files[i].split('/')[-1][0:8] 
  hh = files[i].split('/')[-1][9:11] 

  day_hh = day + " " + hh + ":00:00"
  date_time = datetime.strptime(day_hh, '%Y%m%d %H:%M:%S').strftime('%m-%d-%Y %H:%M:%S')

  sp_list = [dict(item, **{'date_time': date_time}) for item in recording.detections]
  full_data = full_data + sp_list

  print('processing file: ' + date_time)

# %%
with open('/content/drive/MyDrive/IDV/results/field_sp.txt', 'w') as f:
    f.write(str(full_data))

# %%
# plot number: (3) 
# Plot name: Riverside
# ID: 24E1440360371506
# Coordinates (lat, lon):  52.02762751, 6.64777951
# Start date time: 24-05-2023 11:07
# End date time: 25-05-2023 10:02
# Comments: 

folder = '/content/drive/MyDrive/IDV/data/audio/BirdNET/3_riverside/*.WAV'
files = glob.glob(folder)

full_data = []

for i in range(0, len(files)):
  
  analyzer = Analyzer()

  recording = Recording(
      analyzer,
      files[i],
      lat=52.02762751,
      lon= 6.64777951,
      date=datetime(year=2023, month=5, day=24), 
      min_conf=0.5,
  )
  recording.analyze()

  day = files[i].split('/')[-1][0:8] 
  hh = files[i].split('/')[-1][9:11] 

  day_hh = day + " " + hh + ":00:00"
  date_time = datetime.strptime(day_hh, '%Y%m%d %H:%M:%S').strftime('%m-%d-%Y %H:%M:%S')

  sp_list = [dict(item, **{'date_time': date_time}) for item in recording.detections]
  full_data = full_data + sp_list

  print('processing file: ' + date_time)

# %%
with open('/content/drive/MyDrive/IDV/results/riverside_sp.txt', 'w') as f:
    f.write(str(full_data))

# %%
# plot number: (4) 
# Plot name: Forest ending
# ID: 24E144015CC5C82E
# Coordinates (lat, lon): 52.02900199, 6.64948306
# Start date time: 24-05-2023 11:36 
# End date time: 25-05-2023 10:13
# Comments: 

folder = '/content/drive/MyDrive/IDV/data/audio/BirdNET/4_forestending/*.WAV'
files = glob.glob(folder)

full_data = []

for i in range(0, len(files)):
  
  analyzer = Analyzer()

  recording = Recording(
      analyzer,
      files[i],
      lat=52.02900199, 
      lon= 6.64948306,
      date=datetime(year=2023, month=5, day=24), 
      min_conf=0.5,
  )
  recording.analyze()

  day = files[i].split('/')[-1][0:8] 
  hh = files[i].split('/')[-1][9:11] 

  day_hh = day + " " + hh + ":00:00"
  date_time = datetime.strptime(day_hh, '%Y%m%d %H:%M:%S').strftime('%m-%d-%Y %H:%M:%S')

  sp_list = [dict(item, **{'date_time': date_time}) for item in recording.detections]
  full_data = full_data + sp_list

  print('processing file: ' + date_time)

# %%
with open('/content/drive/MyDrive/IDV/results/forestending_sp.txt', 'w') as f:
    f.write(str(full_data))

# %%
# plot number: (5) 
# Plot name: Urban
# ID: 24E144036037151F
# Coordinates (lat, lon): 52.02900199, 6.64948306
# Start date time: 24-05-2023 12:10 
# End date time: 25-05-2023 9:23
# Comments: 

folder = '/content/drive/MyDrive/IDV/data/audio/BirdNET/5_residentialarea/*.WAV'
files = glob.glob(folder)

full_data = []

for i in range(0, len(files)):
  
  analyzer = Analyzer()

  recording = Recording(
      analyzer,
      files[i],
      lat= 52.02900199, 
      lon= 6.64948306,
      date=datetime(year=2023, month=5, day=24), 
      min_conf=0.5,
  )
  recording.analyze()

  day = files[i].split('/')[-1][0:8] 
  hh = files[i].split('/')[-1][9:11] 

  day_hh = day + " " + hh + ":00:00"
  date_time = datetime.strptime(day_hh, '%Y%m%d %H:%M:%S').strftime('%m-%d-%Y %H:%M:%S')

  sp_list = [dict(item, **{'date_time': date_time}) for item in recording.detections]
  full_data = full_data + sp_list

  print('processing file: ' + date_time)

# %%
with open('/content/drive/MyDrive/IDV/results/residentialarea_sp.txt', 'w') as f:
    f.write(str(full_data))

# %% [markdown]
# # Visualization

# %% [markdown]
# # Field

# %%
path = '/content/drive/MyDrive/IDV/results/Birds_detected/field_sp.txt'

with open(path, 'r') as file:
    data_list = eval(file.read())

df = pd.DataFrame(data_list).iloc[:,[0,-1]].sort_values(by=['date_time'])

# %%
all_species = df.groupby(['common_name'])['common_name'].count().to_frame()
all_species = all_species.rename(columns={'common_name': 'number'})
all_species.sort_values(by=all_species.columns[0], ascending=False).reset_index()
# Out:
#                  common_name  number
# 0            Common Redstart     192
# 1          Common Chiffchaff      93
# 2          Eurasian Blackcap      60
# 3         Common Wood-Pigeon      52
# 4     Short-toed Treecreeper      19
# 5              Eurasian Wren      15
# 6           Common Chaffinch       8
# 7                  Great Tit       6
# 8   Great Spotted Woodpecker       5
# 9             Common Buzzard       4
# 10         Eurasian Blue Tit       3
# 11               Song Thrush       3
# 12        Eurasian Blackbird       2
# 13             Common Cuckoo       1
# 14             White Wagtail       1

# %%
df = df.groupby(['common_name', 'date_time'])['common_name'].count().to_frame()
df = df.rename(columns={'common_name': 'number'}).reset_index()

# %%
# Convert 'date_time' column to datetime format
df['date_time'] = pd.to_datetime(df['date_time'], format='%m-%d-%Y %H:%M:%S')

# Create traces for each group
data = []
groups = df.groupby('common_name')
for name, group in groups:
    trace = go.Scatter(
        x=group['date_time'],
        y=group['number'],
        mode='lines+markers',
        line_shape = 'spline',
        name=name
    )
    data.append(trace)

# Create layout

layout = go.Layout(
    title='Field plot',
    xaxis=dict(title='Time', showgrid=True, gridcolor='lightgray'),
    yaxis=dict(title='Number', range=[0, 50], showgrid=True, gridcolor='lightgray'),
)

# Create figure
fig = go.Figure(data=data, layout=layout)

# Show the figure
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="60e23ce0-3527-43fb-829c-7a727618a6a5" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("60e23ce0-3527-43fb-829c-7a727618a6a5")) {                    Plotly.newPlot(                        "60e23ce0-3527-43fb-829c-7a727618a6a5",                        [{"line":{"shape":"spline"},"mode":"lines+markers","name":"Common Buzzard","x":["2023-05-24T13:00:00"],"y":[4],"type":"scatter"},{"line":{"shape":"spline"},"mode":"lines+markers","name":"Common Chaffinch","x":["2023-05-24T10:00:00","2023-05-24T15:00:00","2023-05-24T16:00:00","2023-05-24T19:00:00","2023-05-25T07:00:00"],"y":[1,1,2,1,3],"type":"scatter"},{"line":{"shape":"spline"},"mode":"lines+markers","name":"Common Chiffchaff","x":["2023-05-24T09:00:00","2023-05-24T10:00:00","2023-05-24T11:00:00","2023-05-24T12:00:00","2023-05-24T13:00:00","2023-05-24T14:00:00","2023-05-24T15:00:00","2023-05-24T17:00:00","2023-05-24T18:00:00","2023-05-25T03:00:00","2023-05-25T04:00:00","2023-05-25T05:00:00","2023-05-25T06:00:00"],"y":[6,1,14,1,2,10,4,31,4,1,4,7,8],"type":"scatter"},{"line":{"shape":"spline"},"mode":"lines+markers","name":"Common Cuckoo","x":["2023-05-24T20:00:00"],"y":[1],"type":"scatter"},{"line":{"shape":"spline"},"mode":"lines+markers","name":"Common Redstart","x":["2023-05-24T09:00:00","2023-05-24T10:00:00","2023-05-24T11:00:00","2023-05-24T12:00:00","2023-05-24T13:00:00","2023-05-24T14:00:00","2023-05-24T15:00:00","2023-05-24T17:00:00","2023-05-25T02:00:00","2023-05-25T03:00:00","2023-05-25T04:00:00","2023-05-25T05:00:00","2023-05-25T06:00:00","2023-05-25T07:00:00"],"y":[20,18,10,21,16,15,11,1,38,1,11,19,7,4],"type":"scatter"},{"line":{"shape":"spline"},"mode":"lines+markers","name":"Common Wood-Pigeon","x":["2023-05-24T11:00:00","2023-05-24T13:00:00","2023-05-24T17:00:00","2023-05-24T18:00:00","2023-05-25T06:00:00"],"y":[26,1,4,4,17],"type":"scatter"},{"line":{"shape":"spline"},"mode":"lines+markers","name":"Eurasian Blackbird","x":["2023-05-24T15:00:00"],"y":[2],"type":"scatter"},{"line":{"shape":"spline"},"mode":"lines+markers","name":"Eurasian Blackcap","x":["2023-05-24T09:00:00","2023-05-24T10:00:00","2023-05-24T12:00:00","2023-05-24T13:00:00","2023-05-24T14:00:00","2023-05-24T16:00:00","2023-05-24T17:00:00","2023-05-25T04:00:00","2023-05-25T05:00:00","2023-05-25T06:00:00","2023-05-25T07:00:00"],"y":[1,4,1,29,8,3,2,1,2,4,5],"type":"scatter"},{"line":{"shape":"spline"},"mode":"lines+markers","name":"Eurasian Blue Tit","x":["2023-05-24T10:00:00","2023-05-24T17:00:00"],"y":[1,2],"type":"scatter"},{"line":{"shape":"spline"},"mode":"lines+markers","name":"Eurasian Wren","x":["2023-05-24T09:00:00","2023-05-24T16:00:00","2023-05-24T19:00:00","2023-05-25T05:00:00"],"y":[3,1,10,1],"type":"scatter"},{"line":{"shape":"spline"},"mode":"lines+markers","name":"Great Spotted Woodpecker","x":["2023-05-24T10:00:00","2023-05-24T12:00:00","2023-05-24T14:00:00","2023-05-24T17:00:00","2023-05-25T07:00:00"],"y":[1,1,1,1,1],"type":"scatter"},{"line":{"shape":"spline"},"mode":"lines+markers","name":"Great Tit","x":["2023-05-24T14:00:00","2023-05-24T16:00:00","2023-05-24T18:00:00"],"y":[2,1,3],"type":"scatter"},{"line":{"shape":"spline"},"mode":"lines+markers","name":"Short-toed Treecreeper","x":["2023-05-24T13:00:00","2023-05-24T15:00:00","2023-05-24T18:00:00","2023-05-25T06:00:00"],"y":[11,1,1,6],"type":"scatter"},{"line":{"shape":"spline"},"mode":"lines+markers","name":"Song Thrush","x":["2023-05-24T20:00:00"],"y":[3],"type":"scatter"},{"line":{"shape":"spline"},"mode":"lines+markers","name":"White Wagtail","x":["2023-05-24T12:00:00"],"y":[1],"type":"scatter"}],                        {"title":{"text":"Field plot"},"xaxis":{"gridcolor":"lightgray","showgrid":true,"title":{"text":"Time"}},"yaxis":{"gri ...

# %%
fig.write_html("/content/drive/MyDrive/IDV/results/field.html")

# %% [markdown]
# # Riverside

# %%
path = '/content/drive/MyDrive/IDV/results/Birds_detected/riverside_sp.txt'

with open(path, 'r') as file:
    data_list = eval(file.read())

df = pd.DataFrame(data_list).iloc[:,[0,-1]].sort_values(by=['date_time'])

# %%
all_species = df.groupby(['common_name'])['common_name'].count().to_frame()
all_species = all_species.rename(columns={'common_name': 'number'})
all_species.sort_values(by=all_species.columns[0], ascending=False).reset_index()
# Out:
#                  common_name  number
# 0            Common Redstart     192
# 1          Common Chiffchaff      93
# 2          Eurasian Blackcap      60
# 3         Common Wood-Pigeon      52
# 4     Short-toed Treecreeper      19
# 5              Eurasian Wren      15
# 6           Common Chaffinch       8
# 7                  Great Tit       6
# 8   Great Spotted Woodpecker       5
# 9             Common Buzzard       4
# 10         Eurasian Blue Tit       3
# 11               Song Thrush       3
# 12        Eurasian Blackbird       2
# 13             Common Cuckoo       1
# 14             White Wagtail       1

# %%
df = df.groupby(['common_name', 'date_time'])['common_name'].count().to_frame()
df = df.rename(columns={'common_name': 'number'}).reset_index()

# %%
# Convert 'date_time' column to datetime format
df['date_time'] = pd.to_datetime(df['date_time'], format='%m-%d-%Y %H:%M:%S')

# Create traces for each group
data = []
groups = df.groupby('common_name')
for name, group in groups:
    trace = go.Scatter(
        x=group['date_time'],
        y=group['number'],
        mode='lines+markers',
        line_shape = 'spline',
        name=name
    )
    data.append(trace)

# Create layout
layout = go.Layout(
    title='Riverside plot',
    xaxis=dict(title='Time', showgrid=True, gridcolor='lightgray'),
    yaxis=dict(title='Number', range=[0, 50], showgrid=True, gridcolor='lightgray'),
)

# Create figure
fig = go.Figure(data=data, layout=layout)

# Show the figure
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="a8a2284a-965d-4184-ab98-b95d521b1b7f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a8a2284a-965d-4184-ab98-b95d521b1b7f")) {                    Plotly.newPlot(                        "a8a2284a-965d-4184-ab98-b95d521b1b7f",                        [{"line":{"shape":"spline"},"mode":"lines+markers","name":"Common Buzzard","x":["2023-05-24T13:00:00"],"y":[4],"type":"scatter"},{"line":{"shape":"spline"},"mode":"lines+markers","name":"Common Chaffinch","x":["2023-05-24T10:00:00","2023-05-24T15:00:00","2023-05-24T16:00:00","2023-05-24T19:00:00","2023-05-25T07:00:00"],"y":[1,1,2,1,3],"type":"scatter"},{"line":{"shape":"spline"},"mode":"lines+markers","name":"Common Chiffchaff","x":["2023-05-24T09:00:00","2023-05-24T10:00:00","2023-05-24T11:00:00","2023-05-24T12:00:00","2023-05-24T13:00:00","2023-05-24T14:00:00","2023-05-24T15:00:00","2023-05-24T17:00:00","2023-05-24T18:00:00","2023-05-25T03:00:00","2023-05-25T04:00:00","2023-05-25T05:00:00","2023-05-25T06:00:00"],"y":[6,1,14,1,2,10,4,31,4,1,4,7,8],"type":"scatter"},{"line":{"shape":"spline"},"mode":"lines+markers","name":"Common Cuckoo","x":["2023-05-24T20:00:00"],"y":[1],"type":"scatter"},{"line":{"shape":"spline"},"mode":"lines+markers","name":"Common Redstart","x":["2023-05-24T09:00:00","2023-05-24T10:00:00","2023-05-24T11:00:00","2023-05-24T12:00:00","2023-05-24T13:00:00","2023-05-24T14:00:00","2023-05-24T15:00:00","2023-05-24T17:00:00","2023-05-25T02:00:00","2023-05-25T03:00:00","2023-05-25T04:00:00","2023-05-25T05:00:00","2023-05-25T06:00:00","2023-05-25T07:00:00"],"y":[20,18,10,21,16,15,11,1,38,1,11,19,7,4],"type":"scatter"},{"line":{"shape":"spline"},"mode":"lines+markers","name":"Common Wood-Pigeon","x":["2023-05-24T11:00:00","2023-05-24T13:00:00","2023-05-24T17:00:00","2023-05-24T18:00:00","2023-05-25T06:00:00"],"y":[26,1,4,4,17],"type":"scatter"},{"line":{"shape":"spline"},"mode":"lines+markers","name":"Eurasian Blackbird","x":["2023-05-24T15:00:00"],"y":[2],"type":"scatter"},{"line":{"shape":"spline"},"mode":"lines+markers","name":"Eurasian Blackcap","x":["2023-05-24T09:00:00","2023-05-24T10:00:00","2023-05-24T12:00:00","2023-05-24T13:00:00","2023-05-24T14:00:00","2023-05-24T16:00:00","2023-05-24T17:00:00","2023-05-25T04:00:00","2023-05-25T05:00:00","2023-05-25T06:00:00","2023-05-25T07:00:00"],"y":[1,4,1,29,8,3,2,1,2,4,5],"type":"scatter"},{"line":{"shape":"spline"},"mode":"lines+markers","name":"Eurasian Blue Tit","x":["2023-05-24T10:00:00","2023-05-24T17:00:00"],"y":[1,2],"type":"scatter"},{"line":{"shape":"spline"},"mode":"lines+markers","name":"Eurasian Wren","x":["2023-05-24T09:00:00","2023-05-24T16:00:00","2023-05-24T19:00:00","2023-05-25T05:00:00"],"y":[3,1,10,1],"type":"scatter"},{"line":{"shape":"spline"},"mode":"lines+markers","name":"Great Spotted Woodpecker","x":["2023-05-24T10:00:00","2023-05-24T12:00:00","2023-05-24T14:00:00","2023-05-24T17:00:00","2023-05-25T07:00:00"],"y":[1,1,1,1,1],"type":"scatter"},{"line":{"shape":"spline"},"mode":"lines+markers","name":"Great Tit","x":["2023-05-24T14:00:00","2023-05-24T16:00:00","2023-05-24T18:00:00"],"y":[2,1,3],"type":"scatter"},{"line":{"shape":"spline"},"mode":"lines+markers","name":"Short-toed Treecreeper","x":["2023-05-24T13:00:00","2023-05-24T15:00:00","2023-05-24T18:00:00","2023-05-25T06:00:00"],"y":[11,1,1,6],"type":"scatter"},{"line":{"shape":"spline"},"mode":"lines+markers","name":"Song Thrush","x":["2023-05-24T20:00:00"],"y":[3],"type":"scatter"},{"line":{"shape":"spline"},"mode":"lines+markers","name":"White Wagtail","x":["2023-05-24T12:00:00"],"y":[1],"type":"scatter"}],                        {"title":{"text":"Riverside plot"},"xaxis":{"gridcolor":"lightgray","showgrid":true,"title":{"text":"Time"}},"yaxis":{ ...

# %%
fig.write_html("/content/drive/MyDrive/IDV/results/riverside.html")

# %% [markdown]
# # Forest ending

# %%
path = '/content/drive/MyDrive/IDV/results/Birds_detected/forestending_sp.txt'

with open(path, 'r') as file:
    data_list = eval(file.read())

df = pd.DataFrame(data_list).iloc[:,[0,-1]].sort_values(by=['date_time'])

# %%
all_species = df.groupby(['common_name'])['common_name'].count().to_frame()
all_species = all_species.rename(columns={'common_name': 'number'})
all_species.sort_values(by=all_species.columns[0], ascending=False).reset_index()
# Out:
#                   common_name  number
# 0             Common Redstart     244
# 1           Common Chiffchaff     179
# 2            Common Chaffinch     154
# 3              European Robin      79
# 4           Eurasian Blackcap      74
# 5                 Song Thrush      32
# 6               Eurasian Wren      32
# 7                   Great Tit      10
# 8            Eurasian Jackdaw       8
# 9                        Rook       6
# 10          Eurasian Blue Tit       5
# 11             Common Buzzard       4
# 12     Short-toed Treecreeper       3
# 13                 Stock Dove       2
# 14     Eurasian Golden Oriole       2
# 15               Gray Wagtail       1
# 16        European Greenfinch       1
# 17               Carrion Crow       1
# 18  Eurasian Green Woodpecker       1
# 19          Black-headed Gull       1

# %%
df = df.groupby(['common_name', 'date_time'])['common_name'].count().to_frame()
df = df.rename(columns={'common_name': 'number'}).reset_index()

# %%
# Convert 'date_time' column to datetime format
df['date_time'] = pd.to_datetime(df['date_time'], format='%m-%d-%Y %H:%M:%S')

# Create traces for each group
data = []
groups = df.groupby('common_name')
for name, group in groups:
    trace = go.Scatter(
        x=group['date_time'],
        y=group['number'],
        mode='lines+markers',
        line_shape = 'spline',
        name=name
    )
    data.append(trace)

# Create layout

layout = go.Layout(
    title='Urban plot',
    xaxis=dict(title='Time', showgrid=True, gridcolor='lightgray'),
    yaxis=dict(title='Number', range=[0, 120], showgrid=True, gridcolor='lightgray'),
)

# Create figure
fig = go.Figure(data=data, layout=layout)

# Show the figure
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="57e87d5d-948c-4cd0-b151-ae9ad6abd204" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("57e87d5d-948c-4cd0-b151-ae9ad6abd204")) {                    Plotly.newPlot(                        "57e87d5d-948c-4cd0-b151-ae9ad6abd204",                        [{"line":{"shape":"spline"},"mode":"lines+markers","name":"Black-headed Gull","x":["2023-05-24T11:00:00"],"y":[1],"type":"scatter"},{"line":{"shape":"spline"},"mode":"lines+markers","name":"Carrion Crow","x":["2023-05-24T11:00:00"],"y":[1],"type":"scatter"},{"line":{"shape":"spline"},"mode":"lines+markers","name":"Common Buzzard","x":["2023-05-24T13:00:00","2023-05-24T18:00:00"],"y":[3,1],"type":"scatter"},{"line":{"shape":"spline"},"mode":"lines+markers","name":"Common Chaffinch","x":["2023-05-24T10:00:00","2023-05-24T11:00:00","2023-05-24T12:00:00","2023-05-24T13:00:00","2023-05-24T15:00:00","2023-05-24T18:00:00"],"y":[7,13,114,2,11,7],"type":"scatter"},{"line":{"shape":"spline"},"mode":"lines+markers","name":"Common Chiffchaff","x":["2023-05-24T10:00:00","2023-05-24T11:00:00","2023-05-24T13:00:00","2023-05-24T15:00:00","2023-05-24T16:00:00","2023-05-24T17:00:00","2023-05-24T18:00:00","2023-05-24T19:00:00","2023-05-25T05:00:00","2023-05-25T06:00:00","2023-05-25T07:00:00"],"y":[35,15,33,15,1,38,4,26,2,2,8],"type":"scatter"},{"line":{"shape":"spline"},"mode":"lines+markers","name":"Common Redstart","x":["2023-05-24T10:00:00","2023-05-24T11:00:00","2023-05-24T12:00:00","2023-05-24T13:00:00","2023-05-24T14:00:00","2023-05-24T15:00:00","2023-05-24T16:00:00","2023-05-24T17:00:00","2023-05-24T18:00:00","2023-05-25T02:00:00","2023-05-25T03:00:00","2023-05-25T04:00:00","2023-05-25T05:00:00","2023-05-25T06:00:00","2023-05-25T07:00:00","2023-05-25T08:00:00"],"y":[13,39,63,1,13,22,1,5,7,18,1,7,24,18,2,10],"type":"scatter"},{"line":{"shape":"spline"},"mode":"lines+markers","name":"Eurasian Blackcap","x":["2023-05-24T10:00:00","2023-05-24T11:00:00","2023-05-24T13:00:00","2023-05-24T16:00:00","2023-05-24T18:00:00","2023-05-24T19:00:00","2023-05-25T05:00:00","2023-05-25T07:00:00"],"y":[2,3,35,16,2,1,1,14],"type":"scatter"},{"line":{"shape":"spline"},"mode":"lines+markers","name":"Eurasian Blue Tit","x":["2023-05-24T15:00:00"],"y":[5],"type":"scatter"},{"line":{"shape":"spline"},"mode":"lines+markers","name":"Eurasian Golden Oriole","x":["2023-05-24T18:00:00","2023-05-25T04:00:00"],"y":[1,1],"type":"scatter"},{"line":{"shape":"spline"},"mode":"lines+markers","name":"Eurasian Green Woodpecker","x":["2023-05-25T03:00:00"],"y":[1],"type":"scatter"},{"line":{"shape":"spline"},"mode":"lines+markers","name":"Eurasian Jackdaw","x":["2023-05-25T08:00:00"],"y":[8],"type":"scatter"},{"line":{"shape":"spline"},"mode":"lines+markers","name":"Eurasian Wren","x":["2023-05-24T10:00:00","2023-05-24T14:00:00","2023-05-24T16:00:00","2023-05-24T19:00:00","2023-05-25T08:00:00"],"y":[13,1,2,15,1],"type":"scatter"},{"line":{"shape":"spline"},"mode":"lines+markers","name":"European Greenfinch","x":["2023-05-24T17:00:00"],"y":[1],"type":"scatter"},{"line":{"shape":"spline"},"mode":"lines+markers","name":"European Robin","x":["2023-05-24T12:00:00","2023-05-24T13:00:00","2023-05-24T16:00:00","2023-05-24T17:00:00","2023-05-24T20:00:00"],"y":[1,1,31,39,7],"type":"scatter"},{"line":{"shape":"spline"},"mode":"lines+markers","name":"Gray Wagtail","x":["2023-05-24T12:00:00"],"y":[1],"type":"scatter"},{"line":{"shape":"spline"},"mode":"lines+markers","name":"Great Tit","x":["2023-05-24T15:00:00"],"y":[10],"type":"scatter"},{"line":{"shape":"spline"},"mode":"lines+markers","name":"Rook","x":["2023-05-24T16:00:00","2023-05-25T08:00:00"],"y":[1,5],"type":"scatter"},{"line":{"shape":"spline"},"mode":"lines+markers","name":"Short-toed Treecre ...

# %%
fig.write_html("/content/drive/MyDrive/IDV/results/forestending.html")

# %% [markdown]
# # Urban

# %%
path = '/content/drive/MyDrive/IDV/results/Birds_detected/residentialarea_sp.txt'

with open(path, 'r') as file:
    data_list = eval(file.read())

df = pd.DataFrame(data_list).iloc[:,[0,-1]].sort_values(by=['date_time'])

# %%
all_species = df.groupby(['common_name'])['common_name'].count().to_frame()
all_species = all_species.rename(columns={'common_name': 'number'})
all_species.sort_values(by=all_species.columns[0], ascending=False).reset_index()
# Out:
#                common_name  number
# 0           Black Redstart      68
# 1       European Goldfinch      21
# 2          Common Redstart      19
# 3       Common Wood-Pigeon      16
# 4       Eurasian Blackbird      16
# 5      European Greenfinch      15
# 6         Eurasian Jackdaw      10
# 7                Great Tit      10
# 8        Eurasian Blue Tit       4
# 9         Common Chaffinch       3
# 10  Eurasian Golden Oriole       2
# 11           Mistle Thrush       2
# 12                 Dunnock       1
# 13           White Wagtail       1

# %%
df = df.groupby(['common_name', 'date_time'])['common_name'].count().to_frame()
df = df.rename(columns={'common_name': 'number'}).reset_index()

# %%
# Convert 'date_time' column to datetime format
df['date_time'] = pd.to_datetime(df['date_time'], format='%m-%d-%Y %H:%M:%S')

# Create traces for each group
data = []
groups = df.groupby('common_name')
for name, group in groups:
    trace = go.Scatter(
        x=group['date_time'],
        y=group['number'],
        mode='lines+markers',
        line_shape='spline',
        name=name
    )
    data.append(trace)

# Create layout
layout = go.Layout(
    title='Urban plot',
    xaxis=dict(title='Time', showgrid=True, gridcolor='lightgray'),
    yaxis=dict(title='Number', range=[0, 100], showgrid=True, gridcolor='lightgray'),
)

# Create figure
fig = go.Figure(data=data, layout=layout)

# Show the figure
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="58cc156a-fed0-44fb-8622-30c078a3a3df" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("58cc156a-fed0-44fb-8622-30c078a3a3df")) {                    Plotly.newPlot(                        "58cc156a-fed0-44fb-8622-30c078a3a3df",                        [{"line":{"shape":"spline"},"mode":"lines+markers","name":"Black Redstart","x":["2023-05-25T03:00:00"],"y":[68],"type":"scatter"},{"line":{"shape":"spline"},"mode":"lines+markers","name":"Common Chaffinch","x":["2023-05-24T14:00:00","2023-05-24T19:00:00","2023-05-25T05:00:00"],"y":[1,1,1],"type":"scatter"},{"line":{"shape":"spline"},"mode":"lines+markers","name":"Common Redstart","x":["2023-05-24T13:00:00","2023-05-24T16:00:00","2023-05-25T02:00:00","2023-05-25T04:00:00","2023-05-25T05:00:00","2023-05-25T07:00:00"],"y":[4,1,7,1,4,2],"type":"scatter"},{"line":{"shape":"spline"},"mode":"lines+markers","name":"Common Wood-Pigeon","x":["2023-05-24T18:00:00","2023-05-25T04:00:00","2023-05-25T05:00:00"],"y":[3,8,5],"type":"scatter"},{"line":{"shape":"spline"},"mode":"lines+markers","name":"Dunnock","x":["2023-05-25T04:00:00"],"y":[1],"type":"scatter"},{"line":{"shape":"spline"},"mode":"lines+markers","name":"Eurasian Blackbird","x":["2023-05-24T12:00:00","2023-05-24T15:00:00","2023-05-24T16:00:00","2023-05-24T17:00:00","2023-05-24T20:00:00","2023-05-25T03:00:00"],"y":[1,1,1,11,1,1],"type":"scatter"},{"line":{"shape":"spline"},"mode":"lines+markers","name":"Eurasian Blue Tit","x":["2023-05-24T18:00:00"],"y":[4],"type":"scatter"},{"line":{"shape":"spline"},"mode":"lines+markers","name":"Eurasian Golden Oriole","x":["2023-05-24T12:00:00","2023-05-25T07:00:00"],"y":[1,1],"type":"scatter"},{"line":{"shape":"spline"},"mode":"lines+markers","name":"Eurasian Jackdaw","x":["2023-05-24T18:00:00","2023-05-25T06:00:00"],"y":[5,5],"type":"scatter"},{"line":{"shape":"spline"},"mode":"lines+markers","name":"European Goldfinch","x":["2023-05-24T11:00:00","2023-05-24T12:00:00","2023-05-25T06:00:00","2023-05-25T07:00:00"],"y":[13,1,6,1],"type":"scatter"},{"line":{"shape":"spline"},"mode":"lines+markers","name":"European Greenfinch","x":["2023-05-24T16:00:00","2023-05-25T04:00:00","2023-05-25T05:00:00"],"y":[13,1,1],"type":"scatter"},{"line":{"shape":"spline"},"mode":"lines+markers","name":"Great Tit","x":["2023-05-24T13:00:00","2023-05-24T17:00:00","2023-05-24T18:00:00"],"y":[6,1,3],"type":"scatter"},{"line":{"shape":"spline"},"mode":"lines+markers","name":"Mistle Thrush","x":["2023-05-24T11:00:00","2023-05-24T14:00:00"],"y":[1,1],"type":"scatter"},{"line":{"shape":"spline"},"mode":"lines+markers","name":"White Wagtail","x":["2023-05-24T15:00:00"],"y":[1],"type":"scatter"}],                        {"title":{"text":"Urban plot"},"xaxis":{"gridcolor":"lightgray","showgrid":true,"title":{"text":"Time"}},"yaxis":{"gridcolor":"lightgray","range":[0,100],"showgrid":true,"title":{"text":"Number"}},"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca2 ...

# %%
fig.write_html("/content/drive/MyDrive/IDV/results/urban.html")
